# %%
import pandas as pd
import math
from sklearn.metrics import mean_squared_error as mse
from math import sqrt

# %%
df = pd.read_excel('load_energy_all.xlsx')
df

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['load'] = df['load'].apply(lambda x: x.replace('.','').replace(',','.'))
nordeste_carga_semanal = df[df['submarket']=='Nordeste']
norte_carga_semanal = df[df['submarket']=='Norte']
sudeste_carga_semanal = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_carga_semanal = df[df['submarket']=='Sul']
nordeste_carga_semanal
# Out:
#            date submarket            load    date_str
# 1    2001-07-06  Nordeste   4368.27440476  2001-07-06
# 6    2001-07-13  Nordeste       4496.8625  2001-07-13
# 11   2001-07-20  Nordeste   4508.88392857  2001-07-20
# 16   2001-07-27  Nordeste   4520.65416667  2001-07-27
# 21   2001-08-03  Nordeste   4496.68869048  2001-08-03
# ...         ...       ...             ...         ...
# 5671 2023-03-31  Nordeste  10932.18102381  2023-03-31
# 5676 2023-04-07  Nordeste  10914.65200595  2023-04-07
# 5681 2023-04-14  Nordeste  11216.58897024  2023-04-14
# 5686 2023-04-21  Nordeste  11710.58167857  2023-04-21
# 5691 2023-04-28  Nordeste  11403.56189286  2023-04-28
#
# [1139 rows x 4 columns]

# %%
from google.colab import files
sul_carga_semanal.to_csv('sul_carga_semanal.csv')
files.download('sul_carga_semanal.csv')

# %%
df = pd.read_excel('max_demand_all.xlsx')
df
# Out:
#             date             submarket  max_demand
# 0     06/07/2001              Nordeste       5.330
# 1     06/07/2001                 Norte       2.619
# 2     06/07/2001                   Sul       8.670
# 3     06/07/2001                   SIN      42.208
# 4     06/07/2001  Sudeste/Centro-Oeste      26.065
# ...          ...                   ...         ...
# 5690  28/04/2023                   SIN      86.266
# 5691  28/04/2023  Sudeste/Centro-Oeste      50.130
# 5692  28/04/2023                   Sul      15.705
# 5693  28/04/2023              Nordeste      13.392
# 5694  28/04/2023                 Norte       7.860
#
# [5695 rows x 3 columns]

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
nordeste_max_demand_semanal = df[df['submarket']=='Nordeste']
norte_max_demand_semanal = df[df['submarket']=='Norte']
sudeste_max_demand_semanal = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_max_demand_semanal = df[df['submarket']=='Sul']
nordeste_max_demand_semanal
# Out:
#            date submarket  max_demand
# 0    2001-07-06  Nordeste       5.330
# 5    2001-07-13  Nordeste       5.429
# 10   2001-07-20  Nordeste       5.533
# 15   2001-07-27  Nordeste       5.573
# 21   2001-08-03  Nordeste       5.586
# ...         ...       ...         ...
# 5673 2023-03-31  Nordeste      12.750
# 5675 2023-04-07  Nordeste      13.001
# 5680 2023-04-14  Nordeste      13.224
# 5688 2023-04-21  Nordeste      13.967
# 5693 2023-04-28  Nordeste      13.392
#
# [1139 rows x 3 columns]

# %%
from google.colab import files
sul_max_demand_semanal.to_csv('sul_max_demand_semanal.csv')
files.download('sul_max_demand_semanal.csv')

# %%
df = pd.read_excel('ena_all.xlsx')
df
# Out:
#             date             submarket     ena
# 0     06/07/2001              Nordeste   2.166
# 1     06/07/2001                 Norte   2.223
# 2     06/07/2001  Sudeste/Centro-Oeste  16.977
# 3     06/07/2001                   Sul   8.450
# 4     13/07/2001              Nordeste   1.952
# ...          ...                   ...     ...
# 4551  21/04/2023                   Sul   8.240
# 4552  28/04/2023              Nordeste   4.239
# 4553  28/04/2023                 Norte  25.885
# 4554  28/04/2023  Sudeste/Centro-Oeste  56.481
# 4555  28/04/2023                   Sul   7.305
#
# [4556 rows x 3 columns]

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
nordeste_ena_semanal = df[df['submarket']=='Nordeste']
norte_ena_semanal = df[df['submarket']=='Norte']
sudeste_ena_semanal = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_ena_semanal = df[df['submarket']=='Sul']
nordeste_ena_semanal
# Out:
#            date submarket    ena
# 0    2001-07-06  Nordeste  2.166
# 4    2001-07-13  Nordeste  1.952
# 8    2001-07-20  Nordeste  2.021
# 12   2001-07-27  Nordeste  1.942
# 16   2001-08-03  Nordeste  1.842
# ...         ...       ...    ...
# 4536 2023-03-31  Nordeste  6.759
# 4540 2023-04-07  Nordeste  4.941
# 4544 2023-04-14  Nordeste  4.077
# 4548 2023-04-21  Nordeste  3.849
# 4552 2023-04-28  Nordeste  4.239
#
# [1139 rows x 3 columns]

# %%
from google.colab import files
sul_ena_semanal.to_csv('sul_ena_semanal.csv')
files.download('sul_ena_semanal.csv')

# %%
df = pd.read_excel('hidro_gen_all.xlsx')
df
# Out:
#             date submarket hidro_gen
# 0     06/07/2001  Nordeste   3.036,2
# 1     13/07/2001  Nordeste   3.147,0
# 2     20/07/2001  Nordeste   3.146,3
# 3     27/07/2001  Nordeste   3.165,7
# 4     03/08/2001  Nordeste   3.117,5
# ...          ...       ...       ...
# 4551  31/03/2023       Sul   6.838,2
# 4552  07/04/2023       Sul   4.962,5
# 4553  14/04/2023       Sul   4.730,4
# 4554  21/04/2023       Sul   5.873,1
# 4555  28/04/2023       Sul   6.199,6
#
# [4556 rows x 3 columns]

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['hidro_gen'] = df['hidro_gen'].apply(lambda x: x.replace('.','').replace(',','.'))
nordeste_hidro_gen_semanal = df[df['submarket']=='Nordeste']
norte_hidro_gen_semanal = df[df['submarket']=='Norte']
sudeste_hidro_gen_semanal = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_hidro_gen_semanal = df[df['submarket']=='Sul']
nordeste_hidro_gen_semanal
# Out:
#            date submarket hidro_gen
# 0    2001-07-06  Nordeste    3036.2
# 1    2001-07-13  Nordeste    3147.0
# 2    2001-07-20  Nordeste    3146.3
# 3    2001-07-27  Nordeste    3165.7
# 4    2001-08-03  Nordeste    3117.5
# ...         ...       ...       ...
# 1134 2023-03-31  Nordeste    3595.6
# 1135 2023-04-07  Nordeste    3535.2
# 1136 2023-04-14  Nordeste    3589.8
# 1137 2023-04-21  Nordeste    3590.1
# 1138 2023-04-28  Nordeste    3554.6
#
# [1139 rows x 3 columns]

# %%
norte_hidro_gen_semanal
# Out:
#            date submarket hidro_gen
# 1139 2001-07-06     Norte    2998.7
# 1140 2001-07-13     Norte    2836.5
# 1141 2001-07-20     Norte    2702.3
# 1142 2001-07-27     Norte    2793.1
# 1143 2001-08-03     Norte    2967.8
# ...         ...       ...       ...
# 2273 2023-03-31     Norte   15090.5
# 2274 2023-04-07     Norte   16481.8
# 2275 2023-04-14     Norte   14728.3
# 2276 2023-04-21     Norte   13589.4
# 2277 2023-04-28     Norte   12390.6
#
# [1139 rows x 3 columns]

# %%
from google.colab import files
sul_hidro_gen_semanal.to_csv('sul_hidro_gen_semanal.csv')
files.download('sul_hidro_gen_semanal.csv')

# %%
df = pd.read_excel('thermo_gen_all.xlsx')
df
# Out:
#             date submarket thermo_gen
# 0     06/07/2001  Nordeste       29,9
# 1     13/07/2001  Nordeste       48,3
# 2     20/07/2001  Nordeste       62,1
# 3     27/07/2001  Nordeste       74,7
# 4     03/08/2001  Nordeste       46,3
# ...          ...       ...        ...
# 4551  31/03/2023       Sul    1.009,0
# 4552  07/04/2023       Sul      929,4
# 4553  14/04/2023       Sul      999,3
# 4554  21/04/2023       Sul      973,2
# 4555  28/04/2023       Sul      768,6
#
# [4556 rows x 3 columns]

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['thermo_gen'] = df['thermo_gen'].apply(lambda x: str(x).replace('.','').replace(',','.'))
nordeste_thermo_gen_semanal = df[df['submarket']=='Nordeste']
norte_thermo_gen_semanal = df[df['submarket']=='Norte']
sudeste_thermo_gen_semanal = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_thermo_gen_semanal = df[df['submarket']=='Sul']
nordeste_thermo_gen_semanal
# Out:
#            date submarket thermo_gen
# 0    2001-07-06  Nordeste       29.9
# 1    2001-07-13  Nordeste       48.3
# 2    2001-07-20  Nordeste       62.1
# 3    2001-07-27  Nordeste       74.7
# 4    2001-08-03  Nordeste       46.3
# ...         ...       ...        ...
# 1134 2023-03-31  Nordeste      502.2
# 1135 2023-04-07  Nordeste      487.3
# 1136 2023-04-14  Nordeste      563.1
# 1137 2023-04-21  Nordeste      561.6
# 1138 2023-04-28  Nordeste      508.8
#
# [1139 rows x 3 columns]

# %%
from google.colab import files
sul_thermo_gen_semanal.to_csv('sul_thermo_gen_semanal.csv')
files.download('sul_thermo_gen_semanal.csv')

# %%
df = pd.read_excel('en_arm_all.xlsx')
df
# Out:
#             date             submarket   en_arm
# 0     06/07/2001              Nordeste   11.936
# 1     06/07/2001                 Norte    9.992
# 2     06/07/2001  Sudeste/Centro-Oeste   45.401
# 3     06/07/2001                   Sul   13.788
# 4     13/07/2001              Nordeste   11.446
# ...          ...                   ...      ...
# 4551  21/04/2023                   Sul   17.378
# 4552  28/04/2023              Nordeste   47.111
# 4553  28/04/2023                 Norte   14.966
# 4554  28/04/2023  Sudeste/Centro-Oeste  176.401
# 4555  28/04/2023                   Sul   17.182
#
# [4556 rows x 3 columns]

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
nordeste_en_arm_semanal = df[df['submarket']=='Nordeste']
norte_en_arm_semanal = df[df['submarket']=='Norte']
sudeste_en_arm_semanal = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_en_arm_semanal = df[df['submarket']=='Sul']
nordeste_en_arm_semanal
# Out:
#            date submarket  en_arm
# 0    2001-07-06  Nordeste  11.936
# 4    2001-07-13  Nordeste  11.446
# 8    2001-07-20  Nordeste  11.138
# 12   2001-07-27  Nordeste  10.701
# 16   2001-08-03  Nordeste  10.233
# ...         ...       ...     ...
# 4536 2023-03-31  Nordeste  47.147
# 4540 2023-04-07  Nordeste  47.080
# 4544 2023-04-14  Nordeste  47.051
# 4548 2023-04-21  Nordeste  47.100
# 4552 2023-04-28  Nordeste  47.111
#
# [1139 rows x 3 columns]

# %%
from google.colab import files
sul_en_arm_semanal.to_csv('sul_en_arm_semanal.csv')
files.download('sul_en_arm_semanal.csv')

# %%
df = pd.read_excel('exports_all.xlsx')
df
# Out:
#             date submarket  exports
# 0     06/07/2001  Nordeste   -1.302
# 1     13/07/2001  Nordeste   -1.302
# 2     20/07/2001  Nordeste   -1.301
# 3     27/07/2001  Nordeste   -1.280
# 4     03/08/2001  Nordeste   -1.333
# ...          ...       ...      ...
# 4551  31/03/2023       Sul   -4.524
# 4552  07/04/2023       Sul   -5.418
# 4553  14/04/2023       Sul   -5.985
# 4554  21/04/2023       Sul   -3.592
# 4555  28/04/2023       Sul   -3.945
#
# [4556 rows x 3 columns]

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['imports'] = df['exports'].apply(lambda x: -1000*x if -10 < x < 0 else -x if x <= -10 else 0)
df['exports'] = df['exports'].apply(lambda x: 1000*x if 0 < x < 10 else x if x >= 10 else 0)
nordeste_exports = df[df['submarket']=='Nordeste']
norte_exports = df[df['submarket']=='Norte']
sudeste_exports = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_exports = df[df['submarket']=='Sul']
nordeste_exports
# Out:
#            date submarket  exports  imports
# 0    2001-07-06  Nordeste      0.0   1302.0
# 1    2001-07-13  Nordeste      0.0   1302.0
# 2    2001-07-20  Nordeste      0.0   1301.0
# 3    2001-07-27  Nordeste      0.0   1280.0
# 4    2001-08-03  Nordeste      0.0   1333.0
# ...         ...       ...      ...      ...
# 1134 2023-03-31  Nordeste   1333.0      0.0
# 1135 2023-04-07  Nordeste      0.0    285.0
# 1136 2023-04-14  Nordeste    718.0      0.0
# 1137 2023-04-21  Nordeste      0.0   2056.0
# 1138 2023-04-28  Nordeste   2371.0      0.0
#
# [1139 rows x 4 columns]

# %%
from google.colab import files
sul_exports.to_csv('sul_exports.csv')
files.download('sul_exports.csv')

# %%
df = df.dropna()
import datetime as dt
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df['exports'] = df['exports'].apply(lambda x: -x)
nordeste_exports = df[df['submarket']=='Nordeste']
norte_exports = df[df['submarket']=='Norte']
sudeste_exports = df[df['submarket']=='Sudeste/Centro-Oeste']
sul_exports = df[df['submarket']=='Sul']
norte_exports
# Out:
#            date submarket  exports
# 1139 2001-07-06     Norte -717.000
# 1140 2001-07-13     Norte -600.000
# 1141 2001-07-20     Norte -495.000
# 1142 2001-07-27     Norte -605.000
# 1143 2001-08-03     Norte -747.000
# ...         ...       ...      ...
# 2273 2023-03-31     Norte   -9.271
# 2274 2023-04-07     Norte  -11.127
# 2275 2023-04-14     Norte   -9.755
# 2276 2023-04-21     Norte   -8.554
# 2277 2023-04-28     Norte   -6.610
#
# [1139 rows x 3 columns]

# %%
df_exchanges = pd.concat([nordeste_exports.reset_index().rename(columns={'date':'week_ini_date','exports':'exchange_ne'}),
                          norte_exports.reset_index().rename(columns={'exports':'exchange_n'}),
                          sudeste_exports.reset_index().rename(columns={'exports':'exchange_se'}),
                          sul_exports.reset_index().rename(columns={'exports':'exchange_s'})], axis=1)
df_exchanges = df_exchanges[['week_ini_date','exchange_ne','exchange_n','exchange_se','exchange_s']]
df_exchanges
# Out:
#      week_ini_date  exchange_ne  exchange_n  exchange_se  exchange_s
# 0       2001-07-06        1.302    -717.000      503.000    -744.000
# 1       2001-07-13        1.302    -600.000      291.000    -890.000
# 2       2001-07-20        1.301    -495.000      504.000      -1.108
# 3       2001-07-27        1.280    -605.000      920.000      -1.550
# 4       2001-08-03        1.333    -747.000        1.034      -1.526
# ...            ...          ...         ...          ...         ...
# 1134    2023-03-31       -1.333      -9.271        4.532       4.524
# 1135    2023-04-07      285.000     -11.127        4.351       5.418
# 1136    2023-04-14     -718.000      -9.755        2.442       5.985
# 1137    2023-04-21        2.056      -8.554        1.162       3.592
# 1138    2023-04-28       -2.371      -6.610        3.415       3.945
#
# [1139 rows x 5 columns]

# %%
from google.colab import files
df_exchanges.to_csv('df_exchanges.csv')
files.download('df_exchanges.csv')

# %%
import matplotlib.pyplot as plt

# %%
def get_plot_bar(df, input_name, title):
  df_indexed = df.set_index('week_ini_date')
  # to set the plot size
  plt.figure(figsize=(16, 8), dpi=150)

  # using plot method to plot open prices.
  # in plot method we set the label and color of the curve.
  df_indexed[f'{input_name}_se'].plot(label=f'{input_name}_se', color='orange', kind='bar',stacked=True)
  df_indexed[f'{input_name}_s'].plot(label=f'{input_name}_s', color='blue',kind='bar',stacked=True)
  df_indexed[f'{input_name}_ne'].plot(label=f'{input_name}_ne', color='green',kind='bar',stacked=True)
  df_indexed[f'{input_name}_n'].plot(label=f'{input_name}_n', color='red',kind='bar',stacked=True)

  # adding title to the plot
  plt.title(f'{title}')

  # adding Label to the x-axis
  plt.xlabel('Weekly Observations')

  # adding legend to the curve
  plt.legend()

# %%
get_plot_bar(df_exchanges, 'exchange','Energy Exchange Net (MWmed)')

# %%
df_benchmark_se = pd.read_excel('benchmark_consolidated.xlsx', sheet_name='southeast')
df_benchmark_ne = pd.read_excel('benchmark_consolidated.xlsx', sheet_name='northeast')
df_benchmark_s = pd.read_excel('benchmark_consolidated.xlsx', sheet_name='south')
df_benchmark_n = pd.read_excel('benchmark_consolidated.xlsx', sheet_name='north')
df_benchmark_se
# Out:
#     Unnamed: 0  week       date  actuals  predictions  \
# 0         1018  1019 2021-01-02   297.43   226.775825
# 1         1019  1020 2021-01-09   306.12   241.398587
# 2         1020  1021 2021-01-16   215.56   251.561842
# 3         1021  1022 2021-01-23   184.35   246.212550
# 4         1022  1023 2021-01-30   152.10   248.332710
# 5         1023  1024 2021-02-06   170.45   273.633875
# 6         1024  1025 2021-02-13   173.37   296.835330
# 7         1025  1026 2021-02-20   184.15   311.246859
# 8         1026  1027 2021-02-27   119.64   201.919051
# 9         1027  1028 2021-03-06    70.71   232.104691
# 10        1028  1029 2021-03-13   117.40   247.130641
# 11        1029  1030 2021-03-20   126.23   254.215306
# 12        1030  1031 2021-03-27    99.96   157.073349
# 13        1031  1032 2021-04-03   125.43   194.084518
# 14        1032  1033 2021-04-10   108.77   206.671848
# 15        1033  1034 2021-04-17   161.94   217.783648
# ...

# %%
def trend_direction_accuracy(df_benchmark):
  total = 0
  actual_up = 0
  actual_down = 0
  lstm_up = 0
  lstm_down = 0
  decomp_up = 0
  decomp_down = 0
  stable = 0
  predictions_right_direction = 0
  decomp_right_direction = 0
  for index in df_benchmark.index:
    if index == 0:
      pass
    else:
      if df_benchmark.at[index, 'actuals'] > df_benchmark.at[index-1, 'actuals']:
        actual_up = actual_up + 1
        if df_benchmark.at[index, 'predictions'] > df_benchmark.at[index-1, 'predictions']:
          predictions_right_direction = predictions_right_direction + 1
          lstm_up = lstm_up + 1
        if df_benchmark.at[index, 'decomp_predictions_as_of'] > df_benchmark.at[index-1, 'decomp_predictions_as_of']:
          decomp_right_direction = decomp_right_direction + 1
          decomp_up = decomp_up + 1
      elif df_benchmark.at[index, 'actuals'] < df_benchmark.at[index-1, 'actuals']:
        actual_down = actual_down + 1
        if df_benchmark.at[index, 'predictions'] < df_benchmark.at[index-1, 'predictions']:
          predictions_right_direction = predictions_right_direction + 1
          lstm_down = lstm_down + 1
        if df_benchmark.at[index, 'decomp_predictions_as_of'] < df_benchmark.at[index-1, 'decomp_predictions_as_of']:
          decomp_right_direction = decomp_right_direction + 1
          decomp_down = decomp_down + 1
      else:
        stable = stable + 1
        # if df_benchmark.at[index, 'predictions'] == df_benchmark.at[index-1, 'predictions']:
        #   predictions_right_direction = predictions_right_direction + 1
        # if df_benchmark.at[index, 'decomp_predictions_as_of'] == df_benchmark.at[index-1, 'decomp_predictions_as_of']:
        #   decomp_right_direction = decomp_right_direction + 1
      total = total + 1
  total = total - stable
  print(f'Total trends considered: {total}')
  print(f'Actual UP trends: {actual_up}')
  print(f'Actual DOWN trends: {actual_down}')
  print(f'LSTM UP trends: {lstm_up}')
  print(f'LSTM DOWN trends: {lstm_down}')
  print(f'DECOMP UP trends: {decomp_up}')
  print(f'DECOMP DOWN trends: {decomp_down}')
  print(f'LSTM Trend Direction Accuracy: {(predictions_right_direction/(total))*100}')
  print(f'DECOMP Trend Direction Accuracy: {(decomp_right_direction/(total))*100}')

# %%
trend_direction_accuracy(df_benchmark_se)
trend_direction_accuracy(df_benchmark_ne)
trend_direction_accuracy(df_benchmark_s)
trend_direction_accuracy(df_benchmark_n)
# Out:
# Total trends considered: 25
# Actual UP trends: 16
# Actual DOWN trends: 9
# LSTM UP trends: 15
# LSTM DOWN trends: 4
# DECOMP UP trends: 7
# DECOMP DOWN trends: 6
# LSTM Trend Direction Accuracy: 76.0
# DECOMP Trend Direction Accuracy: 52.0
# Total trends considered: 25
# Actual UP trends: 17
# Actual DOWN trends: 8
# LSTM UP trends: 10
# LSTM DOWN trends: 6
# DECOMP UP trends: 11
# DECOMP DOWN trends: 5
# LSTM Trend Direction Accuracy: 64.0
# DECOMP Trend Direction Accuracy: 64.0
# Total trends considered: 25
# Actual UP trends: 16
# Actual DOWN trends: 9
# LSTM UP trends: 15
# LSTM DOWN trends: 8
# DECOMP UP trends: 7
# DECOMP DOWN trends: 6
# LSTM Trend Direction Accuracy: 92.0
# DECOMP Trend Direction Accuracy: 52.0
# Total trends considered: 24
# Actual UP trends: 16
# Actual DOWN trends: 8
# LSTM UP trends: 8
# LSTM DOWN trends: 7
# DECOMP UP trends: 8
# DECOMP DOWN trends: 3
# LSTM Trend Direction Accuracy: 62.5
# DECOMP Trend Direction Accuracy: 45.83333333333333

# %%
def get_rmse_vol(df_benchmark):
  for index in df_benchmark.index:
    if index == 0:
      df_benchmark.at[index, 'actual_vol'] = 0
      df_benchmark.at[index, 'lstm_vol'] = 0
      df_benchmark.at[index, 'decomp_vol'] = 0
    else:
      df_benchmark.at[index, 'actual_vol'] = ((df_benchmark.at[index, 'actuals'] - df_benchmark.at[index-1, 'actuals'])/df_benchmark.at[index-1, 'actuals'])*100
      df_benchmark.at[index, 'lstm_vol'] = ((df_benchmark.at[index, 'predictions'] - df_benchmark.at[index-1, 'predictions'])/df_benchmark.at[index-1, 'predictions'])*100
      df_benchmark.at[index, 'decomp_vol'] = ((df_benchmark.at[index, 'decomp_predictions_as_of'] - df_benchmark.at[index-1, 'decomp_predictions_as_of'])/df_benchmark.at[index-1, 'decomp_predictions_as_of'])*100
  rmse_lstm_vol = sqrt(mse(df_benchmark['actual_vol'], df_benchmark['lstm_vol']))
  print('RMSE LSTM Vol: %.3f' % rmse_lstm_vol)
  rmse_decomp_vol = sqrt(mse(df_benchmark['actual_vol'], df_benchmark['decomp_vol']))
  print('RMSE DECOMP Vol: %.3f' % rmse_decomp_vol)

# %%
get_rmse_vol(df_benchmark_se)
get_rmse_vol(df_benchmark_ne)
get_rmse_vol(df_benchmark_s)
get_rmse_vol(df_benchmark_n)
# Out:
# RMSE LSTM Vol: 26.067
# RMSE DECOMP Vol: 30.415
# RMSE LSTM Vol: 41.591
# RMSE DECOMP Vol: 41.837
# RMSE LSTM Vol: 25.380
# RMSE DECOMP Vol: 30.582
# RMSE LSTM Vol: 55.534
# RMSE DECOMP Vol: 36.078

# %%
from google.colab import files
df_benchmark_n.to_csv('df_benchmark_n.csv')
files.download('df_benchmark_n.csv')

# %%
def get_rmse_absolute(df_benchmark):
  rmse_lstm = sqrt(mse(df_benchmark['actuals'], df_benchmark['predictions']))
  print('RMSE LSTM Absolute Values: %.3f' % rmse_lstm)
  rmse_decomp = sqrt(mse(df_benchmark['actuals'], df_benchmark['decomp_predictions_as_of']))
  print('RMSE DECOMP Absolute Values: %.3f' % rmse_decomp)

# %%
get_rmse_absolute(df_benchmark_se)
get_rmse_absolute(df_benchmark_ne)
get_rmse_absolute(df_benchmark_s)
get_rmse_absolute(df_benchmark_n)
# Out:
# RMSE LSTM Absolute Values: 107.766
# RMSE DECOMP Absolute Values: 79.395
# RMSE LSTM Absolute Values: 107.537
# RMSE DECOMP Absolute Values: 94.689
# RMSE LSTM Absolute Values: 106.861
# RMSE DECOMP Absolute Values: 79.992
# RMSE LSTM Absolute Values: 92.258
# RMSE DECOMP Absolute Values: 89.607
